# %%
import pandas as pd

df = pd.DataFrame([[1, 2, 3], [4,5,6], [7, 8, 9]], columns=["A", "B", "C"], index=["x", "y", "z"])
# df.index
# df.info()
# df.size
# df.describe()
# df["A"].unique()
# df.shape

# %%
coffee = pd.read_csv('./warmup-data/coffee.csv')
# o_data = pd.read_excel('./data/olympics-data.xlsx', sheet_name="results")

# %%
import numpy as np
# print(coffee.loc[0, "Coffee Type"])
# coffee.index = coffee["Day"]
# coffee.loc["Monday"]
# coffee.Day
# coffee.sort_values(["Units Sold", "Coffee Type"], ascending=[0, 1])
# for index, row in coffee.iterrows():
# coffee['New_Price'] = np.where(coffee['Coffee Type'] == 'Espresso', 3.99, 5.99)
# coffee.drop(columns=["New_Price"], inplace=True)
# coffee['Price'] = np.where(coffee['Coffee Type'] == 'Espresso', 3.99, 5.99)
# coffee['Revenue'] = coffee['Units Sold'] * coffee['Price']
# coffee = coffee.rename(columns={'Price' : 'New Price'})
# coffee.loc[[0, 1], 'Units Sold'] = np.nan
# coffee.fillna(coffee['Units Sold'].mean()) # .interpolate() will look at neighbors to continue trends
# coffee.dropna(subset=['Units Sold']) # Drops any row with NA columns
# .isna() / .notna() to filter na-related row
coffee.groupby(['Coffee Type'])['Units Sold'].sum() # Like an inner join but where the right table is aggregated
coffee.groupby(['Coffee Type', 'Day']).agg({'Units Sold': 'sum', 'New Price': 'mean'}) # Defines aggregate functions for multiple cols
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/bl/y35qk99537b3_6hbz1swmp1m0000gn/T/ipykernel_67770/1580746240.py in ?()
# ---> 18 import numpy as np
#      19 # print(coffee.loc[0, "Coffee Type"])
#      20 # coffee.index = coffee["Day"]
#      21 # coffee.loc["Monday"]
#
# ~/envs/pandas_tutorial/lib/python3.9/site-packages/pandas/core/groupby/generic.py in ?(self, func, engine, engine_kwargs, *args, **kwargs)
#    1267         relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    1268         func = maybe_mangle_lambdas(func)
#    1269
#    1270         op = GroupByApply(self, func, args, kwargs)
# -> 1271         result = op.agg()
#    1272         if not is_dict_like(func) and result is not None:
#    1273             return result
#    1274         elif relabeling:
#
# ...

# %%
def categorize(row):
    if row['height_cm'] < 175 and row['weight_kg'] < 70:
        return 'Lightweight'
    elif row['height_cm'] < 185 or row['weight_kg'] <= 80:
        return 'Middleweight'
    else:
        return 'Heavyweight'

# %%
bios = pd.read_csv('./data/bios.csv')
# bios.loc[(bios['height_cm'] > 215) & (bios['born_country'] == 'USA'), ['name']] # bios[bios['height_cm'] > 215]['name']
# bios[bios['name'].str.contains("keith|patrick", case=False)]
# bios[bios['born_country'].isin(["USA", "FRA", "GBR"]) & (bios['name'].str.startswith("Keith"))]
# bios.query('born_country == "USA" and born_city == "Seattle"') # For SQL
# bios_new = bios.copy()
# bios_new['first_name'] = bios_new['name'].str.split(' ').str[0]
# bios_new.query('first_name == "Keith"')
# bios_new['born_date'] = pd.to_datetime(bios_new['born_date'], format="%Y-%m-%d", errors="coerce") # format for conversion
# bios_new['born_year'] = bios_new['born_date'].dt.year
# bios_new[['name', 'born_year']]
# bios_new.to_csv('./data/bios_new.csv', index=False)
# bios_h = bios.copy()
# bios_h['height_category'] = bios['height_cm'].apply(lambda x: 'Short' if x < 165 else ('Average' if x < 185 else 'Tall'))
# bios_h['weight_category'] = bios.apply(categorize, axis=1)
# bios_h
bios_c = bios.copy()
bios_c[bios_c['born_country'] == 'USA']['born_city'].value_counts()
# Out:
# born_city
# New York        416
# Chicago         283
# Los Angeles     230
# Philadelphia    205
# Boston          153
#                ...
# Ridgecrest        1
# Harriman          1
# Moberly           1
# Fort Arthur       1
# McHenry           1
# Name: count, Length: 2255, dtype: int64

# %%
nocs = pd.read_csv('./data/noc_regions.csv')
results = pd.read_csv('./data/results.csv')

# nocs.head()

# bios_new = pd.merge(bios, nocs, left_on="born_country", right_on="NOC", how='inner', suffixes=["bios", "_t"])
# bios_new

# pd.concat([df_one, df_two]) combines multiple dataframes into one
# Out:
#           year    type              discipline                          event
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)  \
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
pivot = coffee.pivot(columns='Coffee Type', index='Day', values='Revenue')
pivot.sum(axis=1) # axis=0 groups it by coffee type

bios_new['born_date'] = pd.to_datetime(bios_new['born_date'], errors="coerce") # format="%Y-%m-%d" is to change the format for conversion
bios.groupby(bios_new['born_date'].dt.year)['name'].count().reset_index().sort_values('name', ascending=False)
# Out:
#      born_date  name
# 152     1985.0  1954
# 155     1988.0  1903
# 156     1989.0  1902
# 157     1990.0  1893
# 154     1987.0  1884
# ..         ...   ...
# 5       1838.0     1
# 4       1837.0     1
# 3       1836.0     1
# 2       1833.0     1
# 176     2009.0     1
#
# [177 rows x 2 columns]

# %%
coffee['yesterday_revenue'] = coffee['Revenue'].shift(1)
coffee['pct_change'] = coffee['Revenue'] / coffee['yesterday_revenue'] * 100
coffee

bios['height_rank'] = bios['height_cm'].rank()
bios.sort_values(['height_rank'])

coffee['cumulative_revenue'] = coffee['Revenue'].cumsum() # .select_dtypes('float64') for type specificity

latte = coffee[coffee['Coffee Type'] == 'Latte'].copy()
latte['3day'] = latte['Units Sold'].rolling(3).sum() # .rolling will perform agg function on x previous rows at a time

# Look into pyarrow for string optimization #
# results_arrow = pd.read_csv('./data/results.csv', engine='pyarrow', dtype_backend='pyarrow')
